# %%
import scipy.optimize as op
import math
import wavefnplotter as fnplot
import odesolver as solve

def V(x):
    if (x < 0):
        return math.inf
    else:
        return x
    
x0 = 0
xf = 10
dx = 0.01

f = solve.solve_ode(V, 1, x0, xf, 0, 1)

fnplot.plot(f, V, x0, xf, dx)

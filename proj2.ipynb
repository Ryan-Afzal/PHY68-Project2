# %%
import math
import wavefnplotter as fnplot
import odesolver as solve

def V(x):
    if (x < 0):
        return math.inf
    else:
        return x
    
def V1(x):
    if (x < 0):
        return math.inf
    elif (x > 1):
        return math.inf
    else:
        return 0
    
def V2(x):
    return x*x

x0 = 0
xf = 1
dx = 0.01

f = solve.solve_ode(V1, math.pow(math.pi, 2)/2, x0, xf, 0, 1)
#f = solve.solve_ode(V2, 1, x0, xf, 0, 1)

fnplot.plot(f, V1, x0, xf, dx)

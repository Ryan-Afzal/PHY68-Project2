# %%
import math
import wavefnplotter as fnplot
import odesolver as solve
import rootfinder as rf
import scipy.optimize as op
import numpy as np

def V(x):
    if (x < 0):
        return math.inf
    else:
        return x
    
def V1(x):
    if (x < 0):
        return math.inf
    elif (x > 1):
        return math.inf
    else:
        return 0
    
def V2(x):
    return x*x

x0 = 0
xf = 1
dx = 0.01

# rootfind function below
initGuess = 1.9
f = solve.solve_ode(V1, initGuess, x0, xf, 0, 1)
# print(f)
# # def f(x): return math.sin(x)
initGuess = op.fsolve(solve.solve_ode(V1, initGuess, x0, xf, 0, 1), initGuess)[0]
print(initGuess)
f = solve.solve_ode(V1, initGuess, x0, xf, 0, 1)
#f = solve.solve_ode(V2, 1, x0, xf, 0, 1)


fnplot.plot(f, V1, x0, xf, dx)
# Out:
# 1.6174389884075437

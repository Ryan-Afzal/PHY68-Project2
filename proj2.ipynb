# %%
import scipy.optimize as op
import math
import wavefnplotter as fnplot

def f(x):
    return math.sin(x) + 3

#op.newton(f, 6)

def V(x):
    if (x < 0):
        return math.inf
    else:
        return x

fnplot.plot(f, V, 0, 6, 0.01)
